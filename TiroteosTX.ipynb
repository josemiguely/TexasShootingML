# %%
import pandas as pd
import numpy as np
import copy
import datetime as dt
import matplotlib.pyplot as plt
ruta = "Mass Shootings Dataset Ver 5.csv"
df = pd.read_csv(ruta, encoding='cp1252')
df.head()
# Out:
#    S#                                Title                Location  \
# 0   1           Texas church mass shooting  Sutherland Springs, TX
# 1   2  Walmart shooting in suburban Denver            Thornton, CO
# 2   3      Edgewood businees park shooting            Edgewood, MD
# 3   4        Las Vegas Strip mass shooting           Las Vegas, NV
# 4   5           San Francisco UPS shooting       San Francisco, CA
#
#          Date                                Incident Area  \
# 0   11/5/2017                                       Church
# 1   11/1/2017                                     Wal-Mart
# 2  10/18/2017                             Remodeling Store
# 3   10/1/2017  Las Vegas Strip Concert outside Mandala Bay
# 4   6/14/2017                                 UPS facility
#
#   Open/Close Location     Target    Cause  \
# 0               Close     random  unknown
# 1                Open     random  unknown
# 2               Close  coworkers  unknown
# 3                Open     random  unknown
# 4               Close  coworkers      NaN
#
#                                              Summary  Fatalities  ...  \
# 0  Devin Patrick Kelley, 26, an ex-air force offi...          26  ...
# 1  Scott Allen Ostrem, 47, walked into a Walmart ...           3  ...
# 2  Radee Labeeb Prince, 37, fatally shot three pe...           3  ...
# 3  Stephen Craig Paddock, opened fire from the 32...          59  ...
# 4  Jimmy Lam, 38, fatally shot three coworkers an...           3  ...
#
#    Total victims  Policeman Killed  Age Employeed (Y/N)  \
# 0             46               0.0   26             NaN
# 1              3               0.0   47             NaN
# 2              6               0.0   37             NaN
# 3            585               1.0   64             NaN
# 4              5               0.0   38             1.0
#
#              Employed at Mental Health Issues   Race Gender   Latitude  \
# 0                    NaN                   No  White      M        NaN
# 1                    NaN                   No  White      M        NaN
# 2  Advance Granite Store                   No  Black      M        NaN
# 3                    NaN              Unclear  White      M  36.181271
# 4                    NaN                  Yes  Asian      M        NaN
#
#     Longitude
# 0         NaN
# 1         NaN
# 2         NaN
# 3 -115.134132
# 4         NaN
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       S#                           Title                Location        Date  \
# 318  319  Clara Barton Elementary School       Chicago, Illinois   1/17/1974
# 319  320    New Orleans Police Shootings  New Orleans, Louisiana  12/31/1972
# 320  321             St. Aloysius Church     Spokane, Washington  11/11/1971
# 321  322      Rose-Mar College of Beauty           Mesa, Arizona  11/12/1966
# 322  323   University of Texas at Austin           Austin, Texas    8/1/1966
#
#                       Incident Area Open/Close Location    Target      Cause  \
# 318  Clara Barton Elementary School               Close  Teachers      anger
# 319                             NaN                 NaN    random     psycho
# 320                          Church               Close    random  terrorism
# 321      Rose-Mar College of Beauty               Close    random  terrorism
# 322             University of Texas               Close    random  terrorism
#
#                                                Summary  Fatalities  ...  \
# 318  On January 17, 1974, a 14-year-old student ent...           1  ...
# 319  On New Year's Eve in 1972, a 23-year-old ex-Na...          10  ...
# 320  On November 11, 1971, a former MIT student ent...           2  ...
# 321  On November 12, 1966, an 18-year-old high scho...           5  ...
# 322  On August 1, 1966, a 25-year-old engineering s...          17  ...
#
#      Total victims  Policeman Killed  Age Employeed (Y/N)  Employed at  \
# 318              4               0.0   14             NaN          NaN
# 319             22               4.0   23             NaN          NaN
# 320              5               0.0  NaN             NaN          NaN
# 321              6               0.0   18             NaN          NaN
# 322             48               0.0   25             NaN          NaN
#
#     Mental Health Issues                                 Race Gender  \
# 318                  Yes                              Unknown   Male
# 319                  Yes   Black American or African American   Male
# 320                  Yes  White American or European American   Male
# 321                  Yes  White American or European American   Male
# 322                  Yes  White American or European American   Male
#
#       Latitude   Longitude
# 318  41.839280  -87.688181
# 319  30.068724  -89.931474
# 320  47.673674 -117.415984
# 321  33.422687 -111.816320
# 322  30.198887  -97.844159
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#                S#  Fatalities     Injured  Total victims  Policeman Killed  \
# count  323.000000  323.000000  323.000000     323.000000        317.000000
# mean   162.000000    4.436533    6.176471      10.263158          0.129338
# std     93.386294    5.783208   29.889182      33.662309          0.610294
# min      1.000000    0.000000    0.000000       3.000000          0.000000
# 25%     81.500000    1.000000    1.000000       4.000000          0.000000
# 50%    162.000000    3.000000    3.000000       5.000000          0.000000
# 75%    242.500000    5.500000    5.000000       9.000000          0.000000
# max    323.000000   59.000000  527.000000     585.000000          5.000000
#
#        Employeed (Y/N)    Latitude   Longitude
# count        67.000000  303.000000  303.000000
# mean          0.626866   37.225076  -94.429539
# std           0.487288    5.536365   16.513296
# min           0.000000   21.325512 -161.792752
# 25%           0.000000   33.571459 -110.205485
# 50%           1.000000   36.443290  -88.122998
# 75%           1.000000   41.483844  -81.703237
# max           1.000000   60.790539  -69.707823

# %%
cabecera = ["N","Titulo", "Lugar", "Fecha", "Area de incidente", "Espacio Abierto o Cerrado","Objetivo", "Causa", "Resumen", "Muertos", "Heridos", "Victimas Totales", "Policias Muertos", "Edad", "Empleado", "Empleado en", "Problemas mentales", "Raza","Sexo","Latitud","Longitud"]
df.columns = cabecera
df.head()
# Out:
#    N                               Titulo                   Lugar       Fecha  \
# 0  1           Texas church mass shooting  Sutherland Springs, TX   11/5/2017
# 1  2  Walmart shooting in suburban Denver            Thornton, CO   11/1/2017
# 2  3      Edgewood businees park shooting            Edgewood, MD  10/18/2017
# 3  4        Las Vegas Strip mass shooting           Las Vegas, NV   10/1/2017
# 4  5           San Francisco UPS shooting       San Francisco, CA   6/14/2017
#
#                              Area de incidente Espacio Abierto o Cerrado  \
# 0                                       Church                     Close
# 1                                     Wal-Mart                      Open
# 2                             Remodeling Store                     Close
# 3  Las Vegas Strip Concert outside Mandala Bay                      Open
# 4                                 UPS facility                     Close
#
#     Objetivo    Causa                                            Resumen  \
# 0     random  unknown  Devin Patrick Kelley, 26, an ex-air force offi...
# 1     random  unknown  Scott Allen Ostrem, 47, walked into a Walmart ...
# 2  coworkers  unknown  Radee Labeeb Prince, 37, fatally shot three pe...
# 3     random  unknown  Stephen Craig Paddock, opened fire from the 32...
# 4  coworkers      NaN  Jimmy Lam, 38, fatally shot three coworkers an...
#
#    Muertos  ...  Victimas Totales  Policias Muertos  Edad Empleado  \
# 0       26  ...                46               0.0    26      NaN
# 1        3  ...                 3               0.0    47      NaN
# 2        3  ...                 6               0.0    37      NaN
# 3       59  ...               585               1.0    64      NaN
# 4        3  ...                 5               0.0    38      1.0
#
#              Empleado en Problemas mentales   Raza Sexo    Latitud    Longitud
# 0                    NaN                 No  White    M        NaN         NaN
# 1                    NaN                 No  White    M        NaN         NaN
# 2  Advance Granite Store                 No  Black    M        NaN         NaN
# 3                    NaN            Unclear  White    M  36.181271 -115.134132
# 4                    NaN                Yes  Asian    M        NaN         NaN
#
# [5 rows x 21 columns]

# %%
df.describe(include = "all")
# Out:
#                  N   Titulo                Lugar      Fecha Area de incidente  \
# count   323.000000      323                  278        323               261
# unique         NaN      322                  226        290               175
# top            NaN  Killeen  Seattle, Washington  2/20/2016              Home
# freq           NaN        2                    5          4                43
# mean    162.000000      NaN                  NaN        NaN               NaN
# std      93.386294      NaN                  NaN        NaN               NaN
# min       1.000000      NaN                  NaN        NaN               NaN
# 25%      81.500000      NaN                  NaN        NaN               NaN
# 50%     162.000000      NaN                  NaN        NaN               NaN
# 75%     242.500000      NaN                  NaN        NaN               NaN
# max     323.000000      NaN                  NaN        NaN               NaN
#
#        Espacio Abierto o Cerrado Objetivo   Causa  \
# count                        295      318     246
# unique                         4       54      16
# top                        Close   random  psycho
# freq                         197      140      68
# mean                         NaN      NaN     NaN
# std                          NaN      NaN     NaN
# min                          NaN      NaN     NaN
# 25%                          NaN      NaN     NaN
# 50%                          NaN      NaN     NaN
# 75%                          NaN      NaN     NaN
# max                          NaN      NaN     NaN
#
#                                                   Resumen     Muertos  ...  \
# count                                                 323  323.000000  ...
# unique                                                323         NaN  ...
# top     On January 29, 1979, a 16-year-old opened fire...         NaN  ...
# freq                                                    1         NaN  ...
# mean                                                  NaN    4.436533  ...
# std                                                   NaN    5.783208  ...
# min                                                   NaN    0.000000  ...
# 25%                                                   NaN    1.000000  ...
# 50%                                                   NaN    3.000000  ...
# 75%                                                   NaN    5.500000  ...
# max                                                   NaN   59.000000  ...
#
#         Victimas Totales  Policias Muertos  Edad   Empleado  Empleado en  \
# count         323.000000        317.000000   179  67.000000           41
# unique               NaN               NaN    51        NaN           36
# top                  NaN               NaN    34        NaN    Fort Hood
# freq                 NaN               NaN     7        NaN            3
# mean           10.263158          0.129338   NaN   0.626866          NaN
# std            33.662309          0.610294   NaN   0.487288          NaN
# min             3.000000          0.000000   NaN   0.000000          NaN
# 25%             4.000000          0.000000   NaN   0.000000          NaN
# 50%             5.000000          0.000000   NaN   1.000000          NaN
# 75%             9.000000          0.000000   NaN   1.000000          NaN
# max           585.000000          5.000000   NaN   1.000000          NaN
#
#        Problemas mentales                                 Raza  Sexo  \
# count                 323                                  321   323
# unique                  5                                   17     6
# top               Unknown  White American or European American  Male
# freq                  110                                  122   272
# mean                  NaN                                  NaN   NaN
# std                   NaN                                  NaN   NaN
# min                   NaN                                  NaN   NaN
# 25%                   NaN                                  NaN   NaN
# 50%                   NaN                                  NaN   NaN
# 75%                   NaN                                  NaN   NaN
# max                   NaN                                  NaN   NaN
#
#            Latitud    Longitud
# count   303.000000  303.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# mean     37.225076  -94.429539
# std       5.536365   16.513296
# min      21.325512 -161.792752
# 25%      33.571459 -110.205485
# 50%      36.443290  -88.122998
# 75%      41.483844  -81.703237
# max      60.790539  -69.707823
#
# [11 rows x 21 columns]

# %%
columnas = list(df)
for columna in columnas:
    print ("Cantidad de datos sin " + columna + ": " + str(len(df) - df[columna].count()))
    print (str(np.round((len(df) - df[columna].count())/float(len(df))*100,2))+"%")
    print ("-------")
# Out:
# Cantidad de datos sin N: 0
# 0.0%
# -------
# Cantidad de datos sin Titulo: 0
# 0.0%
# -------
# Cantidad de datos sin Lugar: 45
# 13.93%
# -------
# Cantidad de datos sin Fecha: 0
# 0.0%
# -------
# Cantidad de datos sin Area de incidente: 62
# 19.2%
# -------
# Cantidad de datos sin Espacio Abierto o Cerrado: 28
# 8.67%
# -------
# Cantidad de datos sin Objetivo: 5
# 1.55%
# -------
# Cantidad de datos sin Causa: 77
# 23.84%
# -------
# Cantidad de datos sin Resumen: 0
# 0.0%
# -------
# Cantidad de datos sin Muertos: 0
# 0.0%
# -------
# Cantidad de datos sin Heridos: 0
# 0.0%
# -------
# Cantidad de datos sin Victimas Totales: 0
# 0.0%
# -------
# Cantidad de datos sin Policias Muertos: 6
# 1.86%
# -------
# Cantidad de datos sin Edad: 144
# 44.58%
# -------
# Cantidad de datos sin Empleado: 256
# 79.26%
# -------
# Cantidad de datos sin Empleado en: 282
# 87.31%
# -------
# Cantidad de datos sin Problemas mentales: 0
# 0.0%
# -------
# Cantidad de datos sin Raza: 2
# 0.62%
# -------
# Cantidad de datos sin Sexo: 0
# 0.0%
# -------
# Cantidad de datos sin Latitud: 20
# 6.19%
# -------
# Cantidad de datos sin Longitud: 20
# 6.19%
# -------

# %%
df = df.drop(['Resumen','Empleado','Latitud','Longitud','Empleado en','Area de incidente','Espacio Abierto o Cerrado','Objetivo','Causa','Problemas mentales','Policias Muertos','Titulo'], axis=1)

# %%
df.head()
# Out:
#    N                   Lugar       Fecha  Muertos  Heridos  Victimas Totales  \
# 0  1  Sutherland Springs, TX   11/5/2017       26       20                46
# 1  2            Thornton, CO   11/1/2017        3        0                 3
# 2  3            Edgewood, MD  10/18/2017        3        3                 6
# 3  4           Las Vegas, NV   10/1/2017       59      527               585
# 4  5       San Francisco, CA   6/14/2017        3        2                 5
#
#   Edad   Raza Sexo
# 0   26  White    M
# 1   47  White    M
# 2   37  Black    M
# 3   64  White    M
# 4   38  Asian    M

# %%
df.Fecha.unique()
# Out:
# array(['11/5/2017', '11/1/2017', '10/18/2017', '10/1/2017', '6/14/2017',
#        '6/7/2017', '6/5/2017', '5/12/2017', '4/18/2017', '1/6/2017',
#        '9/23/2016', '7/17/2016', '7/7/2016', '6/12/2016', '4/29/2016',
#        '4/26/2016', '4/24/2016', '4/21/2016', '4/19/2016', '4/18/2016',
#        '4/9/2016', '4/7/2016', '4/1/2016', '3/31/2016', '3/26/2016',
#        '3/25/2016', '3/21/2016', '3/20/2016', '3/19/2016', '3/15/2016',
#        '3/13/2016', '3/12/2016', '3/11/2016', '3/9/2016', '3/7/2016',
#        '3/6/2016', '3/5/2016', '2/28/2016', '2/27/2016', '2/26/2016',
#        '2/25/2016', '2/23/2016', '2/21/2016', '2/20/2016', '2/19/2016',
#        '2/9/2016', '2/7/2016', '2/6/2016', '1/31/2016', '1/30/2016',
#        '1/29/2016', '1/27/2016', '1/25/2016', '1/23/2016', '1/17/2016',
#        '1/11/2016', '1/7/2016', '1/6/2016', '12/6/2015', '12/2/2015',
#        '11/27/2015', '11/23/2015', '11/15/2015', '11/13/2015',
#        '11/7/2015', '11/4/2015', '10/31/2015', '10/21/2015', '10/9/2015',
#        '10/1/2015', '9/27/2015', '9/17/2015', '9/10/2015', '8/29/2015',
#        '8/26/2015', '8/19/2015', '8/8/2015', '7/23/2015', '7/22/2015',
#        '7/16/2015', '7/12/2015', '6/20/2015', '6/17/2015', '6/16/2015',
#        '6/11/2015', '6/7/2015', '5/31/2015', '5/25/2015', '5/12/2015',
#        '5/10/2015', '5/3/2015', '5/1/2015', '4/25/2015', '4/21/2015',
#        '4/16/2015', '4/7/2015', '4/5/2015', '4/3/2015', '3/30/2015',
#        '3/28/2015', '3/19/2015', '3/18/2015', '3/15/2015', '3/13/2015',
#        '2/28/2015', '2/27/2015', '2/26/2015', '2/24/2015', '2/22/2015',
#        '2/10/2015', '2/9/2015', '2/7/2015', '2/4/2015', '2/1/2015',
#        '1/28/2015', '1/24/2015', '1/10/2015', '1/1/2015', '12/15/2014',
#        '12/1/2014', '11/19/2014', '10/24/2014', '8/8/2014', '6/29/2014',
#        '6/8/2014', '6/5/2014', '5/23/2014', '4/29/2014', '4/3/2014',
#        '4/2/2014', '3/23/2014', '2/20/2014', '12/28/2013', '11/1/2013',
#        '10/21/2013', '9/16/2013', '8/14/2013', '8/7/2013', '8/5/2013',
#        '7/26/2013', '6/7/2013', '4/24/2013', '4/21/2013', '3/13/2013',
#        '2/19/2013', '2/3/2013', '1/30/2013', '1/19/2013', '12/14/2012',
#        '12/11/2012', '10/21/2012', '9/28/2012', '9/27/2012', '8/5/2012',
#        '7/20/2012', '6/9/2012', '5/30/2012', '5/20/2012', '4/6/2012',
#        '4/2/2012', '2/27/2012', '2/22/2012', '1/29/2012', '10/12/2011',
#        '9/6/2011', '7/7/2011', '4/6/2011', '2/6/2011', '1/8/2011',
#        '8/3/2010', '2/12/2010', '11/29/2009', '11/5/2009', '4/3/2009',
#        '3/29/2009', '3/10/2009', '12/24/2008', '10/26/2008', '7/24/2008',
#        '6/25/2008', '2/14/2008', '2/7/2008', '12/24/2007', '12/11/2007',
#        '12/9/2007', '12/5/2007', '10/25/2007', '10/11/2007', '10/7/2007',
#        '4/16/2007', '4/10/2007', '2/12/2007', '10/2/2006', '9/17/2006',
#        '8/30/2006', '8/24/2006', '3/25/2006', '1/30/2006', '3/21/2005',
#        '3/12/2005', '2/24/2005', '12/8/2004', '11/21/2004', '8/27/2003',
#        '7/8/2003', '5/9/2003', '10/28/2002', '1/16/2002', '3/5/2001',
#        '2/5/2001', '12/26/2000', '12/30/1999', '12/6/1999', '11/2/1999',
#        '9/15/1999', '7/29/1999', '5/20/1999', '4/20/1999', '10/6/1998',
#        '5/21/1998', '4/24/1998', '3/24/1998', '3/6/1998', '12/19/1997',
#        '12/18/1997', '12/1/1997', '10/1/1997', '9/15/1997', '2/19/1997',
#        '8/15/1996', '2/9/1996', '2/2/1996', '11/15/1995', '4/3/1995',
#        '3/21/1995', '1/26/1995', '12/30/1994', '11/7/1994', '6/20/1994',
#        '5/26/1994', '12/16/1993', '12/14/1993', '12/7/1993', '9/17/1993',
#        '8/6/1993', '7/8/1993', '7/1/1993', '5/6/1993', '12/14/1992',
#        '10/15/1992', '9/11/1992', '5/1/1992', '11/14/1991', '11/1/1991',
#        '10/16/1991', '10/10/1991', '8/9/1991', '6/17/1990', '9/14/1989',
#        '8/10/1989', '1/17/1989', '12/14/1988', '9/26/1988', '9/22/1988',
#        '5/20/1988', '2/16/1988', '2/11/1988', '4/23/1987', '12/4/1986',
#        '8/20/1986', '8/12/1986', '3/6/1985', '1/21/1985', '7/18/1984',
#        '6/29/1984', '2/24/1984', '8/19/1983', '2/18/1983', '8/20/1982',
#        '3/19/1982', '10/6/1979', '1/29/1979', '7/12/1976', '2/19/1976',
#        '12/30/1974', '1/17/1974', '12/31/1972', '11/11/1971',
#        '11/12/1966', '8/1/1966'], dtype=object)

# %%
df['Fecha'] = df.apply(lambda row: dt.datetime(int(row.Fecha.split('/')[2]),int(row.Fecha.split('/')[0]),int(row.Fecha.split('/')[1])), axis = 1)

# %%
df.head()
# Out:
#    N                   Lugar      Fecha  Muertos  Heridos  Victimas Totales  \
# 0  1  Sutherland Springs, TX 2017-11-05       26       20                46
# 1  2            Thornton, CO 2017-11-01        3        0                 3
# 2  3            Edgewood, MD 2017-10-18        3        3                 6
# 3  4           Las Vegas, NV 2017-10-01       59      527               585
# 4  5       San Francisco, CA 2017-06-14        3        2                 5
#
#   Edad   Raza Sexo
# 0   26  White    M
# 1   47  White    M
# 2   37  Black    M
# 3   64  White    M
# 4   38  Asian    M

# %%
dict_Sexo = {'M': 1, 'Male': 1, 'Unknown': -1, 'Female':0, 'Male/Female':-1, 'M/F':-1, 'Unclear ':-1}

# %%
df['Sexo'] = df.apply(lambda row: dict_Sexo[row['Sexo']], axis = 1)

# %%
fig, ax = plt.subplots()
df['Fecha'].value_counts().plot(ax=ax, kind='bar')

# %%
df.boxplot(column = 'Heridos',grid = False)
df.hist(column = 'Heridos',grid = False)
df['Heridos'].value_counts()
# Out:
# 0      55
# 3      49
# 2      47
# 1      43
# 4      38
# 5      21
# 6      15
# 7      10
# 9       5
# 10      5
# 12      4
# 13      4
# 14      3
# 8       3
# 21      3
# 11      2
# 19      2
# 20      2
# 23      2
# 32      2
# 527     1
# 70      1
# 16      1
# 24      1
# 25      1
# 30      1
# 53      1
# 15      1
# Name: Heridos, dtype: int64

# %%
df.Raza.unique()
# Out:
# array(['White', 'Black', 'Asian', nan, 'Latino', 'Other', 'Unknown',
#        'Black American or African American',
#        'White American or European American', 'Asian American',
#        'Some other race', 'Two or more races',
#        'Black American or African American/Unknown',
#        'White American or European American/Some other Race',
#        'Native American or Alaska Native', 'white', 'black',
#        'Asian American/Some other race'], dtype=object)

# %%
df['Raza'].replace(np.nan,'Otro',inplace=True)
df.Raza.unique()
# Out:
# array(['White', 'Black', 'Asian', 'Otro', 'Latino', 'Other', 'Unknown',
#        'Black American or African American',
#        'White American or European American', 'Asian American',
#        'Some other race', 'Two or more races',
#        'Black American or African American/Unknown',
#        'White American or European American/Some other Race',
#        'Native American or Alaska Native', 'white', 'black',
#        'Asian American/Some other race'], dtype=object)

# %%
dict_Raza = {'Black': 2, 'Black American or African American': 2,'Black American or African American/Unknown': 2, 'black': 2,'White': 1,'White American or European American': 1,'White American or European American/Some other Race': 1,'white': 1,'Asian': 4,'Asian American': 4,'Asian American/Some other race': 4,'Native American or Alaska Native': 6,'Latino': 5,'Other': 3,'Unknown': 3,'Some other race': 3,'Two or more races': 3,'Otro': 3}

# %%
df['Raza'] = df.apply(lambda row: dict_Raza[row['Raza']], axis = 1)

# %%
df.head()
# Out:
#    N                   Lugar      Fecha  Muertos  Heridos  Victimas Totales  \
# 0  1  Sutherland Springs, TX 2017-11-05       26       20                46
# 1  2            Thornton, CO 2017-11-01        3        0                 3
# 2  3            Edgewood, MD 2017-10-18        3        3                 6
# 3  4           Las Vegas, NV 2017-10-01       59      527               585
# 4  5       San Francisco, CA 2017-06-14        3        2                 5
#
#   Edad  Raza  Sexo
# 0   26     1     1
# 1   47     1     1
# 2   37     2     1
# 3   64     1     1
# 4   38     4     1

# %%
fig, ax = plt.subplots()
df['Raza'].value_counts().plot(ax=ax, kind='bar')

# %%
df.Raza.value_counts()
# Out:
# 1    144
# 2     85
# 3     68
# 4     18
# 5      5
# 6      3
# Name: Raza, dtype: int64

# %%
fig, ax = plt.subplots()
df['Sexo'].value_counts().plot(ax=ax, kind='bar')
df.Sexo.value_counts()
# Out:
#  1    292
# -1     26
#  0      5
# Name: Sexo, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df['Lugar'].value_counts()
# Out:
# Seattle, Washington                                           5
# Phoenix, Arizona                                              4
# Killeen, Texas                                                4
# Tucson, Arizona                                               3
# Omaha, Nebraska                                               3
# Los Angeles, California                                       3
# Las Vegas, Nevada                                             3
# Orlando, Florida                                              3
# New Orleans, Louisiana                                        3
# Cleveland, Ohio                                               3
# Dallas, Texas                                                 3
# Chicago, Illinois                                             3
# Birmingham, Alabama                                           2
# Atlanta, Georgia                                              2
# San Francisco, CA                                             2
# Brookfield, Wisconsin                                         2
# Tulsa, Oklahoma                                               2
# Hesston, Kansas                                               2
# Colorado Springs, Colorado                                    2
# San Bernardino, California                                    2
# Miami, Florida                                                2
# San Diego, California                                         2
# Pittsburgh, Pennsylvania                                      2
# Jacksonville, Florida                                         2
# Louisville, Kentucky                                          2
# Conyers, Georgia                                              2
# Chapel Hill, North Carolina                                   2
# Fort Lauderdale, Florida                                      2
# Aurora, Colorado                                              2
# Fort Hood, Texas                                              2
# Carthage, North Carolina                                      2
# Columbus, Ohio                                                2
# Mesa, Arizona                                                 2
# Menasha, Wisconsin                                            2
# Milwaukee, Wisconsin                                          2
# Minneapolis, Minnesota                                        2
# Meridian, Mississippi                                         1
# Mohawk, New York                                              1
# Moses Lake, Washington                                        1
# Greenville, Georgia                                           1
# Tallahassee, Florida                                          1
# Santee, San Diego, California                                 1
# Santa Clara, California                                       1
# Sunnyvale, California                                         1
# Saginaw, Michigan                                             1
# Norcross, Georgia                                             1
# Honolulu, Hawaii                                              1
# New Port Richey, Florida                                      1
# Orange, California                                            1
# Edinboro, Pennsylvania                                        1
# Montgomery, Alabama                                           1
# Salisbury , Pennsylvania                                      1
# Garden City, New York                                         1
# Carnation, Washington                                         1
# Waycross, Georgia                                             1
# Tunkhannock, PA                                               1
# Washington D.C.                                               1
# Woodbridge,  Virginia                                         1
# Greenwood, South Carolina                                     1
# Oakland, Maine                                                1
# Roseburg, Oregon                                              1
# Brookline, Massachusetts                                      1
# Kennesaw, Georgia                                             1
# Fayetteville, North Carolina                                  1
# Kirkwood, Missouri                                            1
# Morven, North Carolina                                        1
# Albuquerque, New Mexico                                       1
# Aiken, South Carolina                                         1
# Grand Rapids, Michigan                                        1
# Oak Creek, Wisconsin                                          1
# Las Vegas, NV                                                 1
# Lawrenceburg, Tennessee                                       1
# Colerain Township, Ohio                                       1
# Dearborn, Michigan                                            1
# Deer Lodge, Montana                                           1
# Birchwood, Wisconsin                                          1
# San Francisco, California                                     1
# Pennsburg, Souderton, Lansdale, Harleysville, Pennsylvania    1
# Sutherland Springs, TX                                        1
# Lakewood, Washington                                          1
# Wetumpka, Alabama                                             1
# Manchester, Illinois                                          1
# King, North Carolina                                          1
# Flagstaff, Arizona                                            1
# Fullerton, California                                         1
# Ridgewood, New Jersey                                         1
# Wakefield, Massachusetts                                      1
# Decatur, Illinois                                             1
# Springfield, Oregon                                           1
# Richmond, Virginia                                            1
# Chelsea, Michigan                                             1
# Clearbrook (Greenwood), Minnesota                             1
# Tyrone, Missouri                                              1
# Kalamazoo County, Michigan                                    1
# Roanoke, Virginia                                             1
# Parkland, Washington                                          1
# Syracuse, New York                                            1
# Fresno, California                                            1
# Thornton, CO                                                  1
# Tennessee Colony, Texas                                       1
# Houston, Texas                                                1
# Union, Kentucky                                               1
# Santa Barbara, California                                     1
# Olivehurst, California                                        1
# Palm Bay, Florida                                             1
# Goleta, California                                            1
# Burlington, WA                                                1
# Brooklyn, New York                                            1
# Rome, Georgia                                                 1
# Happy Valley, Oregon                                          1
# West Paducah, Kentucky                                        1
# Spokane, Washington                                           1
# Nickel Mines, Lancaster, Pennsylvania                         1
# Ferguson, Missouri                                            1
# Belfair, Washington                                           1
# Newtown, Connecticut                                          1
# Alturas, California                                           1
# Grundy, Virginia                                              1
# Conway, Arkansas                                              1
# Miami Gardens, Florida                                        1
# Glendale, Arizona                                             1
# Suwanee, Georgia                                              1
# River Forest, Illinois                                        1
# Winnetka, Illinois                                            1
# Salt Lake City, Utah                                          1
# Newington, Connecticut                                        1
# Riverside, California                                         1
# Sparks, Nevada                                                1
# Ogden, Utah                                                   1
# Chardon, Ohio                                                 1
# Fairchild Air Force Base, Washington                          1
# Bristol, Tennessee                                            1
# Crandon, Wisconsin                                            1
# Youngstown, Ohio                                              1
# Panama City Beach, Florida                                    1
# Escondido, California                                         1
# Goddard, Kansas                                               1
# Little Water, New Mexico                                      1
# Tyler, Texas                                                  1
# Amarillo, Texas                                               1
# San Ysidro, California                                        1
# Great Barrington, Massachusetts                               1
# Auburn, Alabama                                               1
# Wickliffe, Ohio                                               1
# Fort Worth, Texas                                             1
# Cottonwood, Alabama                                           1
# Carson City, Nevada                                           1
# Oakland, California                                           1
# Edgewood, MD                                                  1
# Hillsborough, North Carolina                                  1
# New York City, New York                                       1
# Stockton, California                                          1
# Indianapolis, Indiana                                         1
# Pearl, Mississippi                                            1
# Edmond, Oklahoma                                              1
# Jonesboro, Arkansas                                           1
# Louisburg, North Carolina                                     1
# Oklahoma City, Oklahoma                                       1
# Austin, Texas                                                 1
# Newark, New Jersey                                            1
# Geneva, Alabama                                               1
# Tampa, Florida                                                1
# Opelika, Alabama                                              1
# Hialeah, Florida                                              1
# Douglasville, Georgia                                         1
# Red Lake, Minnesota                                           1
# Gresham, Oregon                                               1
# Plantation, Florida                                           1
# Corpus Christi, Texas                                         1
# Chelsea, Massachusetts                                        1
# Arvada, Colorado                                              1
# Moscow, Idaho                                                 1
# Littleton, Colorado                                           1
# Federal Way, Washington                                       1
# Seal Beach, California                                        1
# Pinellas Park, Florida                                        1
# Baton Rouge, LA                                               1
# Morgantown, West Virginia                                     1
# Chesapeake, Virginia                                          1
# Blacksburg, Virginia                                          1
# Iowa City, Iowa                                               1
# Royal Oak, Michigan                                           1
# Tarboro, North Carolina                                       1
# South Valley, Albuquerque, New Mexico                         1
# Henderson, Kentucky                                           1
# Charleston, South Carolina                                    1
# Melrose Park, Illinois                                        1
# Monroeville, Pennsylvania                                     1
# Watkins Glen, New York                                        1
# Irvine, California                                            1
# Inglis, Florida                                               1
# Memphis, Tennessee                                            1
# Charlotte, North Carolina                                     1
# DeKalb, Illinois                                              1
# Clarkesville, Georgia                                         1
# Olean, New York                                               1
# Huntsville, Alabama                                           1
# Santa Monica, California                                      1
# Binghamton, New York                                          1
# Lewistown, Montana                                            1
# LaGrange, Georgia                                             1
# Kansas City, Kansas                                           1
# Columbia, South Carolina                                      1
# Montclair, New Jersey                                         1
# Ladera Ranch, California                                      1
# Fort Gibson, Oklahoma                                         1
# Daytona Beach, Florida                                        1
# Kirkersville, Ohio                                            1
# Lancaster County, Pennsylvania                                1
# Brookhaven, Mississippi                                       1
# Essex Junction, Vermont                                       1
# Chattanooga, Tennessee                                        1
# Marysville, Washington                                        1
# Lafayette, Louisiana                                          1
# Iuka, Mississippi                                             1
# Rochester, New York                                           1
# Platte, South Dakota                                          1
# Manchester, Connecticut                                       1
# Sherman, Texas                                                1
# Lynnville, Tennessee                                          1
# Johnston, South Carolina                                      1
# Covina, California                                            1
# Dana Point, California                                        1
# Sheridan, Wyoming                                             1
# Gates, New York                                               1
# Bethel, Alaska                                                1
# Name: Lugar, dtype: int64

# %%
def dict_estado_a_numero():
    dd = {'alabama': 1, 
    'alaska': 2, 
    'arizona': 3, 
    'arkansas': 4, 
    'california': 5,
    'CA':5,
    'north carolina': 6, 
    'south carolina': 7, 
    'colorado': 8,
    'CO': 8,
    'connecticut': 9, 
    'north dakota': 10, 
    'south dakota': 11, 
    'delaware': 12, 
    'florida': 13, 
    'georgia': 14, 
    'hawaii': 15, 
    'idaho': 16, 
    'illinois': 17, 
    'indiana': 18, 
    'iowa': 19, 
    'kansas': 20, 
    'kentucky': 21, 
    'louisiana': 22,
    'LA':22,
    'maine': 23, 
    'maryland': 24,
    'md':24,
    'massachusetts': 25, 
    'michigan': 26, 
    'minnesota': 27, 
    'mississippi': 28, 
    'missouri': 29, 
    'montana': 30, 
    'nebraska': 31, 
    'nevada': 32, 
    'nv':32,
    'new jersey': 33, 
    'new york': 34, 
    'new hampshire': 35, 
    'new mexico': 36, 
    'ohio': 37, 
    'oklahoma': 38, 
    'oregon': 39, 
    'pennsylvania': 40,
    'pa':40,
    'rhode island': 41, 
    'tennessee': 42, 
    'texas': 43,
    'tx': 43,
    'utah': 44, 
    'vermont': 45, 
    'WA':45,
    'virginia': 46, 
    'west virginia': 47, 
    'washington': 48, 
    'wisconsin': 49, 
    'wyoming': 50}
    return dd

# %%
def dict_numero_a_estado():
    dd = {1: 'alabama', 
            2: 'alaska', 
            3: 'arizona', 
            4: 'arkansas', 
            5: 'california', 
            5: 'CA',
            6: 'north carolina', 
            7: 'south carolina', 
            8: 'colorado', 
            8: 'CO',
            9: 'connecticut', 
            10: 'north dakota', 
            11: 'south dakota', 
            12: 'delaware', 
            13: 'florida', 
            14: 'georgia', 
            15: 'hawaii', 
            16: 'idaho', 
            17: 'illinois', 
            18: 'indiana', 
            19: 'iowa', 
            20: 'kansas', 
            21: 'kentucky', 
            22: 'louisiana',
            22: 'LA',
            23: 'maine', 
            24: 'maryland', 
            24: 'md',
            25: 'massachusetts', 
            26: 'michigan', 
            27: 'minnesota', 
            28: 'mississippi', 
            29: 'missouri', 
            30: 'montana', 
            31: 'nebraska', 
            32: 'nevada', 
            32: 'nv',
            33: 'new jersey', 
            34: 'new york', 
            35: 'new hampshire', 
            36: 'new mexico', 
            37: 'ohio', 
            38: 'oklahoma', 
            39: 'oregon', 
            40: 'pennsylvania',
            40: 'pa',
            41: 'rhode island', 
            42: 'tennessee', 
            43: 'texas', 
            43: 'tx',
            44: 'utah', 
            45: 'vermont', 
            45: 'WA',
            46: 'virginia', 
            47: 'west virginia', 
            48: 'washington', 
            49: 'wisconsin', 
            50: 'wyoming'}
    return dd

# %%
def asignar_estado(lugar):
    dd_est_a_nro = dict_estado_a_numero()
    dd_nro_a_est = dict_numero_a_estado()
    
    #Recorremos los distintos valores posibles que consideramos en el diccionario de Estados
    for dd in dd_est_a_nro.keys():
        #Vemos si ese posible estado, está dentro de la palabra lugar, en minúscula para no complicarnos con las Mayusculas
        if dd in lugar.lower():
            #Si está dentro, entonces devolvermos el Estado del segundo diccionario, para unificarlos, cuando estén escritos distintos
            return dd_nro_a_est[dd_est_a_nro[dd]]
    
    #Si no encontró nada, devolvermos un "sin información"
    return "sin informacion"

# %%
df['Lugar'] = df.apply(lambda row: asignar_estado(str(row.Lugar)), axis = 1)
pd.options.display.max_columns = None
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    N            Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 0  1               tx 2017-11-05       26       20                46   26
# 1  2  sin informacion 2017-11-01        3        0                 3   47
# 2  3               md 2017-10-18        3        3                 6   37
# 3  4               nv 2017-10-01       59      527               585   64
# 4  5  sin informacion 2017-06-14        3        2                 5   38
#
#    Raza  Sexo
# 0     1     1
# 1     1     1
# 2     2     1
# 3     1     1
# 4     4     1

# %%
df["N_tiroteo_ultimo_mes"]=np.nan
df["N_tiroteo_ultimos_6mes"]=np.nan
df["N_muertos_ultimo_mes"]=np.nan
df["N_muertos_ultimos_6mes"]=np.nan
df["N_heridos_ultimo_mes"]=np.nan
df["N_heridos_ultimos_6mes"]=np.nan
df["raza_pred_ultimos_12meses"]=np.nan
df["sexo_pred_ultimos_12meses"]=np.nan
df.head()
# Out:
#    N            Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 0  1               tx 2017-11-05       26       20                46   26
# 1  2  sin informacion 2017-11-01        3        0                 3   47
# 2  3               md 2017-10-18        3        3                 6   37
# 3  4               nv 2017-10-01       59      527               585   64
# 4  5  sin informacion 2017-06-14        3        2                 5   38
#
#    Raza  Sexo  N_tiroteo_ultimo_mes  N_tiroteo_ultimos_6mes  \
# 0     1     1                   NaN                     NaN
# 1     1     1                   NaN                     NaN
# 2     2     1                   NaN                     NaN
# 3     1     1                   NaN                     NaN
# 4     4     1                   NaN                     NaN
#
#    N_muertos_ultimo_mes  N_muertos_ultimos_6mes  N_heridos_ultimo_mes  \
# 0                   NaN                     NaN                   NaN
# 1                   NaN                     NaN                   NaN
# 2                   NaN                     NaN                   NaN
# 3                   NaN                     NaN                   NaN
# 4                   NaN                     NaN                   NaN
#
#    N_heridos_ultimos_6mes  raza_pred_ultimos_12meses  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#    sexo_pred_ultimos_12meses
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
import datetime as dt
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
#numero de muertos y heridos ultimo mes
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    fecha_1M = Fecha + relativedelta(days=1) - relativedelta(months=1)
    fecha_aux = (df['Fecha']>=fecha_1M) & (df['Fecha']<=Fecha)
    if len(fecha_aux) == 0:
        N_muertos_ultimo_mes = 0
        N_heridos_ultimo_mes = 0
    else:
        N_muertos_ultimo_mes = df[fecha_aux]['Muertos'].mean()
        N_heridos_ultimo_mes = df[fecha_aux]['Heridos'].mean()
    df.loc[indice,['N_muertos_ultimo_mes']]=N_muertos_ultimo_mes
    df.loc[indice,['N_heridos_ultimo_mes']]=N_heridos_ultimo_mes
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
#numero de muertos y heridos ultimos 6 meses
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    fecha_6M = Fecha + relativedelta(days=1) - relativedelta(months=6)
    fecha_aux = (df['Fecha']>=fecha_6M) & (df['Fecha']<=Fecha)
    if len(fecha_aux) == 0:
        N_muertos_ultimos_6mes = 0
        N_heridos_ultimos_6mes = 0
    else:
        N_muertos_ultimos_6mes = df[fecha_aux]['Muertos'].mean()
        N_heridos_ultimos_6mes = df[fecha_aux]['Heridos'].mean()
    df.loc[indice,['N_muertos_ultimos_6mes']]=N_muertos_ultimos_6mes
    df.loc[indice,['N_heridos_ultimos_6mes']]=N_heridos_ultimos_6mes
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
#raza predominante ultimos 12 meses
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    rfecha_12M = Fecha + relativedelta(days=1) - relativedelta(months=12)
    rfecha_aux = (df['Fecha']>=rfecha_12M) & (df['Fecha']<=Fecha)
    if len(rfecha_aux) == 0:
        raza_pred_ultimos_12meses= -2
    else:
        raza_pred_ultimos_12meses =  df[rfecha_aux]["Raza"]. value_counts(). idxmax()
    df.loc[indice,['raza_pred_ultimos_12meses']]=raza_pred_ultimos_12meses
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
#sexo predominante ultimos 12 meses
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    sfecha_12M = Fecha + relativedelta(days=1) - relativedelta(months=12)
    sfecha_aux = (df['Fecha']>=sfecha_12M) & (df['Fecha']<=Fecha)
    if len(sfecha_aux) == 0:
        sexo_pred_ultimos_12meses= -2
    else:
        sexo_pred_ultimos_12meses =  df[sfecha_aux]["Sexo"]. value_counts(). idxmax()
    df.loc[indice,['sexo_pred_ultimos_12meses']]=sexo_pred_ultimos_12meses
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
df.head()
# Out:
#    N            Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 0  1               tx 2017-11-05       26       20                46   26
# 1  2  sin informacion 2017-11-01        3        0                 3   47
# 2  3               md 2017-10-18        3        3                 6   37
# 3  4               nv 2017-10-01       59      527               585   64
# 4  5  sin informacion 2017-06-14        3        2                 5   38
#
#    Raza  Sexo  N_tiroteo_ultimo_mes  N_tiroteo_ultimos_6mes  \
# 0     1     1                   NaN                     NaN
# 1     1     1                   NaN                     NaN
# 2     2     1                   NaN                     NaN
# 3     1     1                   NaN                     NaN
# 4     4     1                   NaN                     NaN
#
#    N_muertos_ultimo_mes  N_muertos_ultimos_6mes  N_heridos_ultimo_mes  \
# 0             10.666667               13.125000              7.666667
# 1              3.000000               11.285714              1.500000
# 2             31.000000               12.666667            265.000000
# 3             59.000000               12.666667            527.000000
# 4              3.666667                3.666667              0.666667
#
#    N_heridos_ultimos_6mes  raza_pred_ultimos_12meses  \
# 0               69.000000                        1.0
# 1               76.000000                        1.0
# 2               88.666667                        1.0
# 3               88.166667                        1.0
# 4                1.333333                        2.0
#
#    sexo_pred_ultimos_12meses
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0

# %%
#numero de tiroteos ultimo mes
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    fecha_1M = Fecha + relativedelta(days=1) - relativedelta(months=1)
    fecha_aux = (df['Fecha']>=fecha_1M) & (df['Fecha']<=Fecha)
    if len(fecha_aux) == 0:
        N_tiroteo_ultimo_mes = 0
    else:
        N_tiroteo_ultimo_mes = df[fecha_aux]['N'].value_counts().sum()
    df.loc[indice,['N_tiroteo_ultimo_mes']]=N_tiroteo_ultimo_mes
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
#numero de tiroteos ultimos 6 mes
for indice, fila in df.iterrows():
    Fecha = fila['Fecha']
    fecha_6M = Fecha + relativedelta(days=1) - relativedelta(months=6)
    fecha_aux = (df['Fecha']>=fecha_6M) & (df['Fecha']<=Fecha)
    if len(fecha_aux) == 0:
        N_tiroteo_ultimos_6mes = 0
    else:
        N_tiroteo_ultimos_6mes = df[fecha_aux]['N'].value_counts().sum()
    df.loc[indice,['N_tiroteo_ultimos_6mes']]=N_tiroteo_ultimos_6mes
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
df.N_tiroteo_ultimos_6mes.value_counts()
# Out:
# 3.0     35
# 1.0     29
# 2.0     29
# 6.0     19
# 4.0     19
# 7.0     15
# 5.0     15
# 8.0     15
# 9.0     12
# 28.0     9
# 38.0     7
# 30.0     7
# 36.0     6
# 31.0     6
# 42.0     5
# 33.0     5
# 27.0     4
# 73.0     4
# 48.0     4
# 29.0     4
# 32.0     4
# 10.0     4
# 68.0     3
# 67.0     3
# 56.0     3
# 51.0     3
# 14.0     3
# 44.0     2
# 63.0     2
# 59.0     2
# 58.0     2
# 53.0     2
# 65.0     2
# 17.0     2
# 69.0     2
# 20.0     2
# 64.0     2
# 39.0     2
# 40.0     2
# 41.0     2
# 12.0     1
# 66.0     1
# 11.0     1
# 75.0     1
# 15.0     1
# 74.0     1
# 70.0     1
# 76.0     1
# 18.0     1
# 62.0     1
# 61.0     1
# 60.0     1
# 19.0     1
# 45.0     1
# 37.0     1
# 43.0     1
# 35.0     1
# 34.0     1
# 26.0     1
# 25.0     1
# 24.0     1
# 23.0     1
# 22.0     1
# 21.0     1
# 49.0     1
# Name: N_tiroteo_ultimos_6mes, dtype: int64

# %%
df.N_tiroteo_ultimo_mes.value_counts()
# Out:
# 1.0     110
# 2.0      52
# 3.0      30
# 4.0      16
# 7.0      13
# 5.0      12
# 6.0      10
# 8.0       9
# 9.0       8
# 14.0      7
# 22.0      7
# 21.0      6
# 13.0      6
# 23.0      5
# 18.0      4
# 11.0      4
# 10.0      3
# 12.0      3
# 17.0      3
# 25.0      3
# 26.0      2
# 29.0      2
# 24.0      2
# 20.0      2
# 27.0      1
# 19.0      1
# 15.0      1
# 28.0      1
# Name: N_tiroteo_ultimo_mes, dtype: int64

# %%
df.head()
# Out:
#    N            Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 0  1               tx 2017-11-05       26       20                46   26
# 1  2  sin informacion 2017-11-01        3        0                 3   47
# 2  3               md 2017-10-18        3        3                 6   37
# 3  4               nv 2017-10-01       59      527               585   64
# 4  5  sin informacion 2017-06-14        3        2                 5   38
#
#    Raza  Sexo  N_tiroteo_ultimo_mes  N_tiroteo_ultimos_6mes  \
# 0     1     1                   3.0                     8.0
# 1     1     1                   2.0                     7.0
# 2     2     1                   2.0                     6.0
# 3     1     1                   1.0                     6.0
# 4     4     1                   3.0                     6.0
#
#    N_muertos_ultimo_mes  N_muertos_ultimos_6mes  N_heridos_ultimo_mes  \
# 0             10.666667               13.125000              7.666667
# 1              3.000000               11.285714              1.500000
# 2             31.000000               12.666667            265.000000
# 3             59.000000               12.666667            527.000000
# 4              3.666667                3.666667              0.666667
#
#    N_heridos_ultimos_6mes  raza_pred_ultimos_12meses  \
# 0               69.000000                        1.0
# 1               76.000000                        1.0
# 2               88.666667                        1.0
# 3               88.166667                        1.0
# 4                1.333333                        2.0
#
#    sexo_pred_ultimos_12meses
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0

# %%
df.tail()
# Out:
#        N       Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 318  319    illinois 1974-01-17        1        3                 4   14
# 319  320          LA 1972-12-31       10       13                22   23
# 320  321  washington 1971-11-11        2        4                 5  NaN
# 321  322     arizona 1966-11-12        5        1                 6   18
# 322  323          tx 1966-08-01       17       32                48   25
#
#      Raza  Sexo  N_tiroteo_ultimo_mes  N_tiroteo_ultimos_6mes  \
# 318     3     1                   1.0                     1.0
# 319     2     1                   1.0                     1.0
# 320     1     1                   1.0                     1.0
# 321     1     1                   1.0                     2.0
# 322     1     1                   1.0                     1.0
#
#      N_muertos_ultimo_mes  N_muertos_ultimos_6mes  N_heridos_ultimo_mes  \
# 318                   1.0                     1.0                   3.0
# 319                  10.0                    10.0                  13.0
# 320                   2.0                     2.0                   4.0
# 321                   5.0                    11.0                   1.0
# 322                  17.0                    17.0                  32.0
#
#      N_heridos_ultimos_6mes  raza_pred_ultimos_12meses  \
# 318                     3.0                        3.0
# 319                    13.0                        2.0
# 320                     4.0                        1.0
# 321                    16.5                        1.0
# 322                    32.0                        1.0
#
#      sexo_pred_ultimos_12meses
# 318                        1.0
# 319                        1.0
# 320                        1.0
# 321                        1.0
# 322                        1.0

# %%
df["tiroteo_en_tx_mes_pasado"] = np.nan
for indice, fila in df.iterrows():
    fecha = fila['Fecha']
    fecha_1M_mas = fecha + relativedelta(months=1)
    tiroteo_aux = df[(df['Fecha']>fecha) & (df['Fecha']<=fecha_1M_mas) & ((df['Lugar'] == "tx") | (df['Lugar'] == 'texas'))]
    if len(tiroteo_aux) == 0:
        tiroteo = 0
    else:
        tiroteo = 1
    df.loc[indice,["tiroteo_en_tx_mes_pasado"]] = tiroteo
    #print("----------")
    if indice%1000==0:
        print(indice)
# Out:
# 0

# %%
df.head()
# Out:
#    N            Lugar      Fecha  Muertos  Heridos  Victimas Totales Edad  \
# 0  1               tx 2017-11-05       26       20                46   26
# 1  2  sin informacion 2017-11-01        3        0                 3   47
# 2  3               md 2017-10-18        3        3                 6   37
# 3  4               nv 2017-10-01       59      527               585   64
# 4  5  sin informacion 2017-06-14        3        2                 5   38
#
#    Raza  Sexo  N_tiroteo_ultimo_mes  N_tiroteo_ultimos_6mes  \
# 0     1     1                   3.0                     8.0
# 1     1     1                   2.0                     7.0
# 2     2     1                   2.0                     6.0
# 3     1     1                   1.0                     6.0
# 4     4     1                   3.0                     6.0
#
#    N_muertos_ultimo_mes  N_muertos_ultimos_6mes  N_heridos_ultimo_mes  \
# 0             10.666667               13.125000              7.666667
# 1              3.000000               11.285714              1.500000
# 2             31.000000               12.666667            265.000000
# 3             59.000000               12.666667            527.000000
# 4              3.666667                3.666667              0.666667
#
#    N_heridos_ultimos_6mes  raza_pred_ultimos_12meses  \
# 0               69.000000                        1.0
# 1               76.000000                        1.0
# 2               88.666667                        1.0
# 3               88.166667                        1.0
# 4                1.333333                        2.0
#
#    sexo_pred_ultimos_12meses  tiroteo_en_tx_mes_pasado
# 0                        1.0                       0.0
# 1                        1.0                       1.0
# 2                        1.0                       1.0
# 3                        1.0                       0.0
# 4                        1.0                       0.0

# %%
df.tiroteo_en_tx_mes_pasado.value_counts()
# Out:
# 0.0    269
# 1.0     54
# Name: tiroteo_en_tx_mes_pasado, dtype: int64

# %%
list(df.columns)
# Out:
# ['N',
#  'Lugar',
#  'Fecha',
#  'Muertos',
#  'Heridos',
#  'Victimas Totales',
#  'Edad',
#  'Raza',
#  'Sexo',
#  'N_tiroteo_ultimo_mes',
#  'N_tiroteo_ultimos_6mes',
#  'N_muertos_ultimo_mes',
#  'N_muertos_ultimos_6mes',
#  'N_heridos_ultimo_mes',
#  'N_heridos_ultimos_6mes',
#  'raza_pred_ultimos_12meses',
#  'sexo_pred_ultimos_12meses',
#  'tiroteo_en_tx_mes_pasado']

# %%
caracteristicas = ['N_tiroteo_ultimo_mes',
 'N_tiroteo_ultimos_6mes',
 'N_muertos_ultimo_mes',
 'N_muertos_ultimos_6mes',
 'N_heridos_ultimo_mes',
 'N_heridos_ultimos_6mes',
 'raza_pred_ultimos_12meses',
 "sexo_pred_ultimos_12meses"]

# %%
X = df.loc[:,caracteristicas].to_numpy()

# %%
etiqueta = ['tiroteo_en_tx_mes_pasado']
y = df.loc[:,etiqueta].to_numpy()

# %%
sum(y)/float(len(y))*100 #porcentaje de que ocurrio tiroteo mes pasado con respecto al total
# Out:
# array([16.71826625])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
ad = DecisionTreeClassifier() # Creando el modelo

# %%
#Entreno el modelo
ad.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Realizo una predicción
Y_pred = ad.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
tn, fp, fn, tp = confusion_matrix(y_test, Y_pred).ravel()

# %%
print('tn: ' + str(tn))
print('fp: ' + str(fp))
print('fn: ' + str(fn))
print('tp: ' + str(tp))
# Out:
# tn: 63
# fp: 3
# fn: 3
# tp: 12

# %%
correctitud = (tp+tn)/float(tp+fp+fn+tn)
sensibilidad = (tp)/float(tp+fn)
especificidad = (tn)/float(fp+tn)
precision = (tp)/float(tp+fp)
tasa_real = (tp+fn)/float(tp+fp+fn+tn)
f1_score = 2*(precision*sensibilidad)/float(precision+sensibilidad)

# %%
print("correctitud: " + str(np.round(correctitud*100,2)) + "%") #de acierto de tiroteo
print("sensibilidad: " + str(np.round(sensibilidad*100,2)) + "%") #de acierto solo sobre el exito 
print("especificidad: " + str(np.round(especificidad*100,2)) + "%") #de acierto solo sobre el no exito
print("precision: " + str(np.round(precision*100,2)) + "%") #sobre lo que dijo que si, acierto
print("tasa_real: " + str(np.round(tasa_real*100,2)) + "%") #tasa de tiroteos c/r al total
print("f1_score: " + str(np.round(f1_score*100,2)) + "%") #mezcla precision con sensibilidad
# Out:
# correctitud: 92.59%
# sensibilidad: 80.0%
# especificidad: 95.45%
# precision: 80.0%
# tasa_real: 18.52%
# f1_score: 80.0%

# %%
from sklearn import tree

# %%
with open("mi_arbol.dot", 'w') as archivo_dot:
    tree.export_graphviz(ad, out_file = archivo_dot, filled=True, rounded=True, special_characters=False, impurity=False, feature_names=caracteristicas)

# %%
# utilizando el lenguaje dot para graficar el arbol.
# !dot -Tjpeg mi_arbol.dot -o arbol_decision.pdf
# Out:
# "dot" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %%
cross_val_score(DecisionTreeClassifier(), X, y, cv=10, scoring='f1') #cv=10 cantidad de grupos que queremos que pruebe, "f1score para los valores que genero grupos de 10"
# Out:
# array([0.5       , 0.92307692, 0.44444444, 0.41666667, 0.57142857,
#        0.25      , 0.33333333, 0.75      , 0.33333333, 0.        ])

# %%
np.mean(cross_val_score(DecisionTreeClassifier(), X, y, cv=10, scoring='f1')) #promedio indicadores
# Out:
# 0.4192454212454212

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
CV_RF = (cross_val_score(RandomForestClassifier(), X, y, cv=10, scoring='f1'))
# Out:
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\users\jose miguel\proyectos\tiroteoseeuu\env\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
CV_RF
# Out:
# array([0.6       , 0.70588235, 0.6       , 0.58823529, 0.66666667,
#        0.33333333, 0.33333333, 0.33333333, 0.        , 0.        ])

# %%
np.mean(CV_RF)
# Out:
# 0.4160784313725491

# %%
df.boxplot(column = 'Muertos',grid = False)
df.hist(column = 'Muertos',grid = False)
df['Muertos'].value_counts()
# Out:
# 1     46
# 3     45
# 0     41
# 2     38
# 5     38
# 4     34
# 6     27
# 7     14
# 8      9
# 9      7
# 10     5
# 13     3
# 12     2
# 14     2
# 15     2
# 11     1
# 49     1
# 16     1
# 17     1
# 22     1
# 24     1
# 26     1
# 28     1
# 32     1
# 59     1
# Name: Muertos, dtype: int64

# %%
df.boxplot(column = 'Sexo',grid = False)
df.hist(column = 'Sexo',grid = False)
df['Sexo'].value_counts()
# Out:
#  1    292
# -1     26
#  0      5
# Name: Sexo, dtype: int64

# %%
fig, ax = plt.subplots()
df['Sexo'].value_counts().plot(ax=ax, kind='bar')
